# %% [markdown]
# ## Using Incline
#
# We showcase how to use **incline** using data from the stock market.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Load Google Daily Stock Price Data
#
# Convert the date column to date, sort by date, and index the dataframe by date.

# %%
df = pd.read_csv('data/GOOG.csv')
df.Date = pd.to_datetime(df.Date)
df.sort_values('Date', inplace=True)
df.set_index('Date', inplace=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %% [markdown]
# ### Using incline
#
# We start by importing the functions and then fit spline_trend and sgolay_trend to the Closing value of the stock

# %%
from incline import naive_trend, spline_trend, sgolay_trend, trending

# %%
df1 = spline_trend(df, column_value='Close',  function_order=3, derivative_order=1, s=50000)
df1['id'] = 'GOOG-Close-spline'
df1.head()
# Out:
# /Users/soodoku/Documents/GitHub/incline/incline/trend.py:128: UserWarning: Time series appears irregularly sampled. Consider interpolation or using spline methods.
#   x, _delta = compute_time_deltas(df.index)
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400
#
#             smoothed_value  derivative_value  function_order  \
# Date
# 2004-08-19       53.517454         -0.450033               3
# 2004-08-20       53.088515         -0.407944               3
# 2004-08-23       52.050069         -0.285244               3
# 2004-08-24       51.784731         -0.245532               3
# 2004-08-25       51.558807         -0.206415               3
#
#            derivative_method  derivative_order  smoothing_parameter  \
# Date
# 2004-08-19            spline                 1              50000.0
# 2004-08-20            spline                 1              50000.0
# 2004-08-23            spline                 1              50000.0
# 2004-08-24            spline                 1              50000.0
# 2004-08-25            spline                 1              50000.0
#
#                            id
# Date
# 2004-08-19  GOOG-Close-spline
# 2004-08-20  GOOG-Close-spline
# 2004-08-23  GOOG-Close-spline
# 2004-08-24  GOOG-Close-spline
# 2004-08-25  GOOG-Close-spline

# %%
df2 = sgolay_trend(df, column_value='Close',  function_order=3, derivative_order=1)
df2['id'] = 'GOOG-Close-sgolay'
df2.head()
# Out:
# /Users/soodoku/Documents/GitHub/incline/incline/trend.py:208: UserWarning: Time series appears irregularly sampled. Consider interpolation or using spline methods.
#   x, delta = compute_time_deltas(df.index)
# /Users/soodoku/Documents/GitHub/incline/incline/trend.py:217: UserWarning: Time series appears irregularly sampled. Consider interpolation or using spline methods.
#   x, _ = compute_time_deltas(df.index)
# /var/folders/ks/1g8bn5m566n_w4l5hwwjv4180000gn/T/ipykernel_97239/742553626.py:1: UserWarning: Savitzky-Golay assumes uniform sampling. Consider spline methods for irregular time series.
#   df2 = sgolay_trend(df, column_value='Close',  function_order=3, derivative_order=1)
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400
#
#             smoothed_value  derivative_value  function_order  \
# Date
# 2004-08-19       51.099678          1.563686               3
# 2004-08-20       52.363147          0.977906               3
# 2004-08-23       53.084794          0.480041               3
# 2004-08-24       53.352533          0.070091               3
# 2004-08-25       53.254281         -0.251943               3
#
#            derivative_method  derivative_order  edge_region                 id
# Date
# 2004-08-19            sgolay                 1         True  GOOG-Close-sgolay
# 2004-08-20            sgolay                 1         True  GOOG-Close-sgolay
# 2004-08-23            sgolay                 1         True  GOOG-Close-sgolay
# 2004-08-24            sgolay                 1         True  GOOG-Close-sgolay
# 2004-08-25            sgolay                 1         True  GOOG-Close-sgolay

# %%
fig, axes = plt.subplots(2, 1)
axes[0].set_title('GOOG-Close-spline');
axes[1].set_title('GOOG-Close-sgolay');
df1[['Close', 'smoothed_value']][:100].plot(figsize=(12, 16), secondary_y='smoothed_value', ax=axes[0], style=['-', '--']);
df2[['Close', 'smoothed_value']][:100].plot(figsize=(12, 16), secondary_y='smoothed_value', ax=axes[1]);

# %%
tdf = trending([df1, df2], derivative_order=1, max_or_avg='max')
tdf
# Out:
#                   id  max_or_avg  rank
# 0  GOOG-Close-spline   16.150474     1
# 1  GOOG-Close-sgolay   13.407763     2

# %%
df3 = naive_trend(df, column_value='Close')
df3.head()
# Out:
# /Users/soodoku/Documents/GitHub/incline/incline/trend.py:64: UserWarning: Time series appears irregularly sampled. Consider interpolation or using spline methods.
#   x, delta = compute_time_deltas(df.index)
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400
#
#             derivative_value derivative_method function_order  \
# Date
# 2004-08-19          3.959248             naive           None
# 2004-08-20          2.250363             naive           None
# 2004-08-23         -0.854443             naive           None
# 2004-08-24         -0.844507             naive           None
# 2004-08-25          0.755088             naive           None
#
#             derivative_order
# Date
# 2004-08-19                 1
# 2004-08-20                 1
# 2004-08-23                 1
# 2004-08-24                 1
# 2004-08-25                 1

# %%
fig = plt.figure()
ax = plt.axes()
plt.plot(df3[['derivative_value']][:100], color = "blue", label = "naive")
plt.plot(df2[['derivative_value']][:100], color = "green", label = "SG")
plt.plot(df1[['derivative_value']][:100], color = "black", label = "Spline")
plt.legend()

# %% [markdown]
# ## Correlations Between Naive, Spline, and Savitzky-Golay Derivative Est.

# %%
df1[['derivative_value']].corrwith(df2[['derivative_value']], axis = 0)
# Out:
# derivative_value    0.61238
# dtype: float64

# %%
df2[['derivative_value']].corrwith(df3[['derivative_value']], axis = 0)
# Out:
# derivative_value    0.660056
# dtype: float64
